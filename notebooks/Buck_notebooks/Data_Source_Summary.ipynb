# %% [markdown]
# # Data and Source Summary

# %% [markdown]
# ### JRA vs CERES Comparison:
# - CERES data derived from https://ceres.larc.nasa.gov/Data/ - all sky component
# - JRA data derived from Gadi notebook at /g/data/qv56/replicas/input4MIPs/CMIP6/OMIP/MRI/""MRI-JRA55-do-1-4-0
#
# ### DWLW Eval Map and Animation
# - JRA data from gadi directory /g/data/qv56/replicas/input4MIPs/CMIP6/OMIP/MRI/MRI-JRA55-do-1-4-0/atmos/3hr/rlds/gr/v20190429
# - CERES data derived from same as above
#
# ### PAPA SST plot
# - PAPA sst mooring data from https://www.pmel.noaa.gov/ocs/data/disdel/
#
# ### PAPA and SOTS TS and CTD Profiles
# - PAPA shipboard data from map search at https://cchdo.ucsd.edu/search?bbox=-151.0840,42.9403,-125.0684,52.4828 - each ship voyage in the list (you can find through filenames)
# - SOTS shipboard data from same site but different map box search https://cchdo.ucsd.edu/search?bbox=136.9336,-53.7487,155.5664,-44.8403
#
# ### All PAPA flux comparison (Net_sfc, SW, LW, Latent, Sensible)
# - PAPA data from https://www.pmel.noaa.gov/ocs/data/fluxdisdel/ as a computed flux
#
# ### Humidity and Wind JRA
# - 2m Specific humidity and 10m wind speed from https://www.pmel.noaa.gov/ocs/data/fluxdisdel/ also as computed flux component
#
# ## All datasets will be pased in relevant folders within my notebook folder in the github for easy access. They should also be available in my ob1561 folder within jk72 in gadi
