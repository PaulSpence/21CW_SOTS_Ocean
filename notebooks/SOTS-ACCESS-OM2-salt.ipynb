# %%
def collect_data(var, local_path, region, start_date, end_date):

    var_arr  = []

    cleaned_list = [item for item in local_path if item != []]

    
    for item,file in enumerate(cleaned_list):

        print(f'reading file: {file.split("/")[-1]}, {item+1}/{len(cleaned_list)}')
        sys.stdout.flush()
        
        with xr.open_dataset(file,decode_timedelta=False) as ds:

            time_range = ds['time'].sel(time=slice(start_date, end_date))

            data = ds[var].sel(time=time_range,\
                            yt_ocean=slice(region[0][0], region[0][1]), \
                            xt_ocean=slice(region[1][0], region[1][1])).load()
            
            data = data.mean(dim=["yt_ocean", "xt_ocean"]) 
            
    
            original_units = ds[var].attrs.get('units', '')
            
        if original_units:
            data.attrs['units'] = original_units
    
        var_arr.append(data)

    return  var_arr

# %%
client = Client()
client
# Out:
# /home/562/cd3007/miniconda3/envs/mhw_env/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40749 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:34529' processes=6 threads=24, memory=95.00 GiB>

# %%
import os
import re
import sys
import intake
import numpy as np
import pandas as pd
import scipy as io
import xarray as xr
import matplotlib.dates as mdates

from mpi4py import MPI
from datetime import date, datetime, timedelta
from matplotlib import pyplot as plt
from dask.distributed import Client


catalog = intake.cat.access_nri


print('Starting ACCESS-OM2 SOTS analysis....')
sys.stdout.flush()

clim_start = 2004
clim_end = 2018

start_date = np.datetime64("2004-01-01")
end_date = np.datetime64("2018-12-31")

var   =  'salt'

access_model='01deg_jra55v140_iaf'
deg = '01deg'


region_lat   = np.array([-50,-45])                    # yt_ocean,N
region_lon   = np.array([145,150])                    # xt_ocean,E
region_lon   = region_lon - 360                         # -> [-213, -205]

region = [region_lat, region_lon]


#----------------------------------------------------------------------------------------------
# This section collects all the variable paths
#----------------------------------------------------------------------------------------------
path_dict = {var: []}


catalog_filtered = catalog[access_model].search(
    variable=var,
    frequency='1mon',
    realm='ocean',
    
)

df = catalog_filtered.df[
    (catalog_filtered.df['start_date'] >= '2004-01-01') & 
    (catalog_filtered.df['start_date'] <= '2018-12-31') &
    (catalog_filtered.df['filename'].str.contains('mean'))
]

file_list = df['path'].tolist()

path_dict[var].extend(file_list)
path_dict[var].sort(key=lambda f: tuple(map(int, re.search(r'ym_(\d{4})_(\d{2})', f).groups())))


print(f'Processing {var} variable...')
sys.stdout.flush()


path_list = path_dict[var]

print(f'Scattering path for {var}...')
sys.stdout.flush()
    

local_var = collect_data(var,path_list, region, start_date, end_date)

local_var = xr.concat(local_var, dim='time')

monthly_climatology = local_var.groupby('time.month').mean('time')

anomaly = local_var.groupby('time.month') - monthly_climatology

units = local_var.attrs.get("units", "")

anomaly.attrs['units'] = units

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)

anomaly.plot(
    ax=axes[0],
    x='time',
    y='st_ocean',
    cmap='viridis',
    yincrease=False,
    cbar_kwargs={'label': f'{var} anomaly (m/s)'}
)
axes[0].set_title(f"Hovmöller Diagram: {var} anomaly (0–5000 m)")
axes[0].set_ylabel("Depth (m)")
axes[0].set_ylim(5000, 0)

anomaly.plot(
    ax=axes[1],
    x='time',
    y='st_ocean',
    cmap='viridis',
    yincrease=False,
    add_colorbar=False  
)
axes[1].set_title(f"Hovmöller Diagram: {var} anomaly (0–200 m)")
axes[1].set_ylabel("Depth (m)")
axes[1].set_xlabel("Time")
axes[1].set_ylim(1000, 0)

for ax in axes:
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.tight_layout()
plt.show()
# Out:
# Starting ACCESS-OM2 SOTS analysis....
# Processing salt variable...
# Scattering path for salt...
# reading file: ocean-3d-salt-1-monthly-mean-ym_2004_01.nc, 1/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2004_04.nc, 2/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2004_07.nc, 3/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2004_10.nc, 4/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2005_01.nc, 5/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2005_04.nc, 6/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2005_07.nc, 7/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2005_10.nc, 8/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2006_01.nc, 9/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2006_04.nc, 10/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2006_07.nc, 11/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2006_10.nc, 12/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2007_01.nc, 13/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2007_04.nc, 14/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2007_07.nc, 15/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2007_10.nc, 16/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2008_01.nc, 17/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2008_04.nc, 18/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2008_07.nc, 19/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2008_10.nc, 20/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2009_01.nc, 21/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2009_04.nc, 22/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2009_07.nc, 23/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2009_10.nc, 24/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2010_01.nc, 25/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2010_04.nc, 26/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2010_07.nc, 27/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2010_10.nc, 28/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2011_01.nc, 29/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2011_04.nc, 30/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2011_07.nc, 31/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2011_10.nc, 32/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2012_01.nc, 33/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2012_04.nc, 34/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2012_07.nc, 35/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2012_10.nc, 36/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2013_01.nc, 37/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2013_04.nc, 38/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2013_07.nc, 39/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2013_10.nc, 40/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2014_01.nc, 41/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2014_04.nc, 42/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2014_07.nc, 43/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2014_10.nc, 44/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2015_01.nc, 45/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2015_04.nc, 46/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2015_07.nc, 47/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2015_10.nc, 48/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2016_01.nc, 49/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2016_04.nc, 50/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2016_07.nc, 51/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2016_10.nc, 52/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2017_01.nc, 53/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2017_04.nc, 54/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2017_07.nc, 55/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2017_10.nc, 56/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2018_01.nc, 57/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2018_04.nc, 58/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2018_07.nc, 59/60
# reading file: ocean-3d-salt-1-monthly-mean-ym_2018_10.nc, 60/60
