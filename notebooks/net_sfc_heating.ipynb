# %%
import os
import re
import sys
import glob
import intake
import numpy as np
import pandas as pd
import scipy as io
import xarray as xr
import matplotlib.dates as mdates

from mpi4py import MPI
from datetime import date, datetime, timedelta
from matplotlib import pyplot as plt
from dask.distributed import Client

# %%
#----------------------------------------------------------------------------------------------
# Function to read file and collect data for SOTS region
#----------------------------------------------------------------------------------------------

def collect_data(var, local_path, region, start_date, end_date):

    var_arr  = []

    cleaned_list = [item for item in local_path if item != []]

    
    for item,file in enumerate(cleaned_list):

        print(f'reading file: {file.split("/")[-1]}, {item+1}/{len(cleaned_list)}')
        sys.stdout.flush()
        
        with xr.open_dataset(file,decode_timedelta=False) as ds:

            time_range = ds['time'].sel(time=slice(start_date, end_date))

            data = ds[var].sel(time=time_range,\
                            yt_ocean=slice(region[0][0], region[0][1]), \
                            xt_ocean=slice(region[1][0], region[1][1])).load()
            
            data = data.mean(dim=["yt_ocean", "xt_ocean"]) 
            
    
            original_units = ds[var].attrs.get('units', '')
            
        if original_units:
            data.attrs['units'] = original_units
    
        var_arr.append(data)

    return  var_arr

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:40505' processes=1 threads=1, memory=125.19 GiB>

# %%
catalog = intake.cat.access_nri


print('Starting ACCESS-OM2 SOTS net surface heat flux analysis....')
sys.stdout.flush()

#----------------------------------------------------------------------------------------------
# Date of interest 
#----------------------------------------------------------------------------------------------

start_date = np.datetime64("2010-01-01")
end_date = np.datetime64("2023-12-31")

#----------------------------------------------------------------------------------------------
# Variable of interest in ACCESS-OM1-O1
#----------------------------------------------------------------------------------------------

var   =  'net_sfc_heating'

access_model=['01deg_jra55v140_iaf','01deg_jra55v140_iaf_cycle4_jra55v150_extension']
deg = '01deg'

#----------------------------------------------------------------------------------------------
# Variable of interest of SOTS
#----------------------------------------------------------------------------------------------

var_SOTS   =  'HEAT_NET'
#----------------------------------------------------------------------------------------------
# Region of interest
#----------------------------------------------------------------------------------------------

region_lat   = np.array([-50,-45])                    # yt_ocean,N
region_lon   = np.array([145,150])                    # xt_ocean,E
region_lon   = region_lon - 360                         # -> [-213, -205]

region = [region_lat, region_lon]

#----------------------------------------------------------------------------------------------
# This section collects all the variable paths for ACCESS-OM2
#----------------------------------------------------------------------------------------------
path_dict = {var: []}

catalogs = []

for model in access_model:
    filtered = catalog[model].search(
        variable=var,
        frequency='1mon',
        realm='ocean',
    )
    catalogs.append(filtered.df)

# Concatenate the dataframes from all models
combined_df = pd.concat(catalogs, ignore_index=True)

df = combined_df[
    (combined_df['start_date'] >= '2010-01-01') &
    (combined_df['start_date'] <= '2023-12-31') &
    (combined_df['filename'].str.contains('mean'))
]


file_list = df['path'].tolist()

path_dict[var].extend(file_list)
path_dict[var].sort(key=lambda f: tuple(map(int, re.search(r'ym_(\d{4})_(\d{2})', f).groups())))


print(f'Processing {var} variable...')
sys.stdout.flush()

path_list = path_dict[var]

#----------------------------------------------------------------------------------------------
# Call function to read path and collect data
#----------------------------------------------------------------------------------------------

local_var = collect_data(var, path_list, region, start_date, end_date)

heat_flux = xr.concat(local_var, dim='time')  # join all time together

dates = heat_flux['time'].values

units = heat_flux.attrs.get("units", "")

heat_flux.attrs['units'] = units

# Get climatology
monthly_climatology = heat_flux.groupby('time.month').mean(dim='time')

years = np.unique(heat_flux['time.year'].values)
# Out:
# Starting ACCESS-OM2 SOTS net surface heat flux analysis....
# Processing net_sfc_heating variable...
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2010_01.nc, 1/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2010_04.nc, 2/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2010_07.nc, 3/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2010_10.nc, 4/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2011_01.nc, 5/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2011_04.nc, 6/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2011_07.nc, 7/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2011_10.nc, 8/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2012_01.nc, 9/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2012_04.nc, 10/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2012_07.nc, 11/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2012_10.nc, 12/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2013_01.nc, 13/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2013_04.nc, 14/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2013_07.nc, 15/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2013_10.nc, 16/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2014_01.nc, 17/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2014_04.nc, 18/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2014_07.nc, 19/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2014_10.nc, 20/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2015_01.nc, 21/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2015_04.nc, 22/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2015_07.nc, 23/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2015_10.nc, 24/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2016_01.nc, 25/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2016_04.nc, 26/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2016_07.nc, 27/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2016_10.nc, 28/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2017_01.nc, 29/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2017_04.nc, 30/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2017_07.nc, 31/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2017_10.nc, 32/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2018_01.nc, 33/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2018_04.nc, 34/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2018_07.nc, 35/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2018_10.nc, 36/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_01.nc, 37/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_02.nc, 38/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_03.nc, 39/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_04.nc, 40/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_05.nc, 41/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_06.nc, 42/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_07.nc, 43/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_08.nc, 44/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_09.nc, 45/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_10.nc, 46/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_11.nc, 47/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2019_12.nc, 48/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_01.nc, 49/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_02.nc, 50/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_03.nc, 51/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_04.nc, 52/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_05.nc, 53/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_06.nc, 54/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_07.nc, 55/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_08.nc, 56/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_09.nc, 57/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_10.nc, 58/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_11.nc, 59/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2020_12.nc, 60/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_01.nc, 61/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_02.nc, 62/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_03.nc, 63/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_04.nc, 64/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_05.nc, 65/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_06.nc, 66/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_07.nc, 67/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_08.nc, 68/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_09.nc, 69/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_10.nc, 70/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_11.nc, 71/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2021_12.nc, 72/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_01.nc, 73/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_02.nc, 74/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_03.nc, 75/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_04.nc, 76/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_05.nc, 77/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_06.nc, 78/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_07.nc, 79/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_08.nc, 80/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_09.nc, 81/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_10.nc, 82/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_11.nc, 83/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2022_12.nc, 84/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_01.nc, 85/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_02.nc, 86/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_03.nc, 87/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_04.nc, 88/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_05.nc, 89/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_06.nc, 90/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_07.nc, 91/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_08.nc, 92/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_09.nc, 93/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_10.nc, 94/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_11.nc, 95/96
# reading file: ocean-2d-net_sfc_heating-1-monthly-mean-ym_2023_12.nc, 96/96

# %%
#----------------------------------------------------------------------------------------------
# Read and collect data for SOTS
#----------------------------------------------------------------------------------------------

print(f'Processing SOTS data...')
sys.stdout.flush()


SOTS_dir  = '/g/data/jk72/mxr581/SOTS-project-data/sots/flux'
SOTS_pattern = os.path.join(SOTS_dir, "IMOS_DWM-*_CFMST_20*.nc")

SOTS_paths = sorted(glob.glob(SOTS_pattern))

ds = xr.open_mfdataset(
    SOTS_paths,
    combine='nested',
    concat_dim='TIME',
    data_vars='minimal',
    coords='minimal',
    compat='override',
    preprocess=lambda ds: ds.sortby('TIME')  # sort each dataset's time coordinate
)[[var_SOTS]]


SOTS_flux = ds[var_SOTS]

# Get climatology
SOTS_monthly_climatology = SOTS_flux.groupby('TIME.month').mean(dim='TIME')

SOTS_years = np.unique(SOTS_flux['TIME.year'].values)

print(f'Finished collecting SOTS data.')
sys.stdout.flush()
# Out:
# Processing SOTS data...
# Finished collecting SOTS data.

# %%
#----------------------------------------------------------------------------------------------
# PLOTS
#----------------------------------------------------------------------------------------------

fig, axs = plt.subplots(1, 2, figsize=(20, 8), sharey=True)

# ACCESS data on left plot
for yr in years:
    
    yearly = heat_flux.sel(time=str(yr))

    # Get monthly values
    months = yearly['time'].dt.month
    monthly_vals = yearly.values

    axs[0].plot(months, monthly_vals,
                label=str(yr), alpha=0.4, marker='o', linestyle='--')

axs[0].plot(monthly_climatology['month'], monthly_climatology.values,
            label='Climatology', color='black', linewidth=3)

axs[0].set_xlabel('Month')
axs[0].set_ylabel('Net Surface Heat Flux (W/m²) [positive into ocean]')
axs[0].set_title('Net Surface Heat Flux (ACCESS)')
axs[0].set_xticks(np.arange(1, 13))
axs[0].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
axs[0].legend(ncol=2, fontsize='small', loc='upper left', bbox_to_anchor=(1.05, 1))

# SOTS data on right plot
for yr in SOTS_years:

    yearly = SOTS_flux.sel(TIME=str(yr))

    monthly_mean = yearly.groupby('TIME.month').mean(dim='TIME')
    months = monthly_mean['month']
    monthly_vals = monthly_mean.values

    axs[1].plot(months, monthly_vals,
                label=str(yr), alpha=0.4, marker='o', linestyle='--')

axs[1].plot(SOTS_monthly_climatology['month'], SOTS_monthly_climatology.values,
            label='Climatology', color='black', linewidth=3)

axs[1].set_xlabel('Month')
axs[1].set_ylabel('Net Surface Heat Flux (W/m²)')
axs[1].set_title('Net Surface Heat Flux (SOTS)')
axs[1].set_xticks(np.arange(1, 13))
axs[1].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
axs[1].legend(ncol=2, fontsize='small', loc='upper left', bbox_to_anchor=(1.05, 1))

plt.tight_layout()
plt.show()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/client.py:3363: UserWarning: Sending large graph of size 35.91 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
